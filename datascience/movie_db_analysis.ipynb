# %%
import pandas as pd

# %%
df = pd.read_csv(
    "./datasets/mymoviedb.csv",
    encoding="utf-8",
)
df.tail()
# Out:
#      Release_Date                                 Title  \
# 9822   1973-10-15                              Badlands
# 9823   2020-10-01                      Violent Delights
# 9824   2016-05-06                          The Offering
# 9825   2021-03-31  The United States vs. Billie Holiday
# 9826   1984-09-23                               Threads
#
#                                                Overview  Popularity  \
# 9822  A dramatization of the Starkweather-Fugate kil...      13.357
# 9823  A female vampire falls in love with a man she ...      13.356
# 9824  When young and successful reporter Jamie finds...      13.355
# 9825  Billie Holiday spent much of her career being ...      13.354
# 9826  Documentary style account of a nuclear holocau...      13.354
#
#       Vote_Count  Vote_Average Original_Language                        Genre  \
# 9822       896.0           7.6                en                 Drama, Crime
# ...

# %%
df[(df["Vote_Average"] > 8.0)].head(20)
# Out:
#     Release_Date                                              Title  \
# 0     2021-12-15                            Spider-Man: No Way Home
# 1     2022-03-01                                         The Batman
# 20    2021-12-01                                             Sing 2
# 28    2020-10-16  Demon Slayer -Kimetsu no Yaiba- The Movie: Mug...
# 44    2022-03-10                                        Turning Red
# 48    2021-10-15                                   Ron's Gone Wrong
# 50    2021-05-26                                            Cruella
# 56    2021-03-18                       Zack Snyder's Justice League
# 68    2021-11-04                                              Finch
# 71    2018-04-25                             Avengers: Infinity War
# 125   2020-11-21          Miraculous World: New York, United HeroeZ
# 127   2019-12-20                    My Hero Academia: Heroes Rising
# 135   2016-10-07                                      Hacksaw Ridge
# ...

# %%
df[(df["Vote_Average"] > 8.0) & (df["Genre"].str.contains("Drama, Crime"))].head(20)
# Out:
#      Release_Date                        Title  \
# 609    1972-03-14                The Godfather
# 657    1994-09-23     The Shawshank Redemption
# 731    1999-12-10               The Green Mile
# 1007   1974-12-20       The Godfather: Part II
# 1759   1990-09-12                   GoodFellas
# 2384   1984-05-23  Once Upon a Time in America
# 2784   2002-02-05                  City of God
# 3260   1995-07-19           The Usual Suspects
#
#                                                Overview  Popularity  \
# 609   Spanning the years 1945 to 1955, a chronicle o...      93.136
# 657   Framed in the 1940s for the double murder of h...      87.669
# 731   A supernatural tale set on death row in a Sout...      81.142
# 1007  In the continuing saga of the Corleone crime f...      65.324
# 1759  The true story of Henry Hill, a half-Irish, ha...      44.572
# 2384  A former Prohibition-era Jewish gangster retur...      35.818
# ...
