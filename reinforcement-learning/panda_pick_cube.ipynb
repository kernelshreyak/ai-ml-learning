# %%
import os
import time
import math
import numpy as np
import gymnasium as gym
from gymnasium import spaces

import pybullet as p
import pybullet_data

import os
import gymnasium as gym
from gymnasium.wrappers import RecordVideo

import multiprocessing as mp

from stable_baselines3 import PPO
from stable_baselines3.common.vec_env import SubprocVecEnv, VecMonitor
# Out:
# pybullet build time: Jan 29 2025 23:16:28

# %%
class PandaPickCubeEnv(gym.Env):
    """
    Franka Panda end-effector control with IK.
    Task: pick up a cuboid (random size) from a table and move it to a target on the table.

    Notes:
      - CPU-based physics (PyBullet) -> scale with SubprocVecEnv for throughput.
      - Observation includes cube size to allow generalization across sizes.
    """
    metadata = {"render_modes": ["human", "rgb_array"], "render_fps": 60}

    def __init__(
        self,
        render_mode=None,
        episode_len=200,
        sim_steps_per_action=8,
        cube_size_range=(0.02, 0.06),  # half-extent range in meters
        target_xy_range=0.15,
        seed=None,
    ):
        super().__init__()
        self.render_mode = render_mode
        self.episode_len = episode_len
        self.sim_steps_per_action = sim_steps_per_action
        self.cube_size_range = cube_size_range
        self.target_xy_range = target_xy_range

        self._rng = np.random.default_rng(seed)

        # Action: delta EE xyz + gripper command
        # dx,dy,dz in [-1,1] scaled internally, grip in [-1,1] (close/open)
        self.action_space = spaces.Box(low=-1.0, high=1.0, shape=(4,), dtype=np.float32)

        # Observation: ee_pos(3), ee_vel(3), cube_pos(3), cube_vel(3), target_pos(3), cube_size(3), gripper_width(1)
        obs_dim = 3 + 3 + 3 + 3 + 3 + 3 + 1
        self.observation_space = spaces.Box(low=-np.inf, high=np.inf, shape=(obs_dim,), dtype=np.float32)

        self._client = None
        self._step_count = 0

        # IDs
        self.panda = None
        self.cube_id = None
        self.table_id = None

        # Panda joints
        self.arm_joint_indices = [0, 1, 2, 3, 4, 5, 6]
        self.finger_joint_indices = [9, 10]  # depends on URDF; works for standard panda in pybullet_data
        self.ee_link_index = 11  # panda_hand
        self.max_gripper_opening = 0.08  # approximate

        # Goal
        self.target_pos = None

        # Internal control scaling
        self.ee_delta_scale = np.array([0.02, 0.02, 0.02], dtype=np.float32)  # meters per action
        self.ee_min = np.array([0.25, -0.3, 0.05], dtype=np.float32)
        self.ee_max = np.array([0.75, 0.3, 0.55], dtype=np.float32)

    def _connect(self):
        if self._client is not None:
            return
        if self.render_mode == "human":
            self._client = p.connect(p.GUI)
        else:
            self._client = p.connect(p.DIRECT)

        p.resetSimulation(physicsClientId=self._client)
        p.setAdditionalSearchPath(pybullet_data.getDataPath(), physicsClientId=self._client)
        p.setGravity(0, 0, -9.81, physicsClientId=self._client)
        p.setTimeStep(1.0 / 240.0, physicsClientId=self._client)

    def _load_scene(self):
        p.resetSimulation(physicsClientId=self._client)
        p.setAdditionalSearchPath(pybullet_data.getDataPath(), physicsClientId=self._client)
        p.setGravity(0, 0, -9.81, physicsClientId=self._client)
        p.setTimeStep(1.0 / 240.0, physicsClientId=self._client)

        p.loadURDF("plane.urdf", physicsClientId=self._client)

        # Table
        table_urdf = os.path.join(pybullet_data.getDataPath(), "table/table.urdf")
        self.table_id = p.loadURDF(table_urdf, basePosition=[0.5, 0.0, -0.65], useFixedBase=True, physicsClientId=self._client)

        # Panda
        self.panda = p.loadURDF(
            "franka_panda/panda.urdf",
            basePosition=[0.0, 0.0, 0.0],
            useFixedBase=True,
            physicsClientId=self._client,
        )

        # Set joint damping
        for j in range(p.getNumJoints(self.panda, physicsClientId=self._client)):
            p.changeDynamics(self.panda, j, linearDamping=0.04, angularDamping=0.04, physicsClientId=self._client)

        # Default pose
        home = [0.0, -0.6, 0.0, -2.2, 0.0, 1.6, 0.8]
        for idx, q in zip(self.arm_joint_indices, home):
            p.resetJointState(self.panda, idx, q, physicsClientId=self._client)

        # Open gripper
        self._set_gripper(opening=self.max_gripper_opening)

        # Spawn cube with randomized half-extents (variable cuboid size)
        hx = float(self._rng.uniform(*self.cube_size_range))
        hy = float(self._rng.uniform(*self.cube_size_range))
        hz = float(self._rng.uniform(*self.cube_size_range))
        self.cube_half_extents = np.array([hx, hy, hz], dtype=np.float32)

        cube_col = p.createCollisionShape(p.GEOM_BOX, halfExtents=[hx, hy, hz], physicsClientId=self._client)
        cube_vis = p.createVisualShape(p.GEOM_BOX, halfExtents=[hx, hy, hz], rgbaColor=[0.8, 0.2, 0.2, 1.0], physicsClientId=self._client)

        cube_x = float(self._rng.uniform(0.45, 0.65))
        cube_y = float(self._rng.uniform(-0.15, 0.15))
        cube_z = 0.02  # slightly above table surface
        self.cube_id = p.createMultiBody(
            baseMass=0.2,
            baseCollisionShapeIndex=cube_col,
            baseVisualShapeIndex=cube_vis,
            basePosition=[cube_x, cube_y, cube_z],
            baseOrientation=p.getQuaternionFromEuler([0, 0, float(self._rng.uniform(-math.pi, math.pi))]),
            physicsClientId=self._client,
        )
        p.changeDynamics(self.cube_id, -1, lateralFriction=1.0, spinningFriction=0.01, rollingFriction=0.01, physicsClientId=self._client)

        # Sample target on table (xy random, z fixed at table height)
        tx = float(self._rng.uniform(0.45, 0.65))
        ty = float(self._rng.uniform(-self.target_xy_range, self.target_xy_range))
        tz = 0.02
        self.target_pos = np.array([tx, ty, tz], dtype=np.float32)

    def _set_gripper(self, opening: float):
        opening = float(np.clip(opening, 0.0, self.max_gripper_opening))
        # Each finger moves half the opening
        finger_pos = opening / 2.0
        for j in self.finger_joint_indices:
            p.setJointMotorControl2(
                self.panda, j,
                p.POSITION_CONTROL,
                targetPosition=finger_pos,
                force=80,
                physicsClientId=self._client
            )

    def _get_gripper_opening(self):
        s9 = p.getJointState(self.panda, self.finger_joint_indices[0], physicsClientId=self._client)[0]
        s10 = p.getJointState(self.panda, self.finger_joint_indices[1], physicsClientId=self._client)[0]
        return float(s9 + s10)

    def _get_ee_state(self):
        link = p.getLinkState(self.panda, self.ee_link_index, computeLinkVelocity=1, physicsClientId=self._client)
        pos = np.array(link[4], dtype=np.float32)
        vel = np.array(link[6], dtype=np.float32)
        return pos, vel

    def _ik_to(self, ee_pos, ee_orn=None):
        if ee_orn is None:
            # fixed orientation: gripper pointing down
            ee_orn = p.getQuaternionFromEuler([math.pi, 0, 0])
        joint_poses = p.calculateInverseKinematics(
            self.panda,
            self.ee_link_index,
            ee_pos.tolist(),
            ee_orn,
            maxNumIterations=50,
            residualThreshold=1e-4,
            physicsClientId=self._client,
        )
        return joint_poses

    def _apply_action(self, action):
        action = np.asarray(action, dtype=np.float32)
        dxyz = action[:3] * self.ee_delta_scale
        grip_cmd = float(action[3])

        ee_pos, _ = self._get_ee_state()
        target_ee = np.clip(ee_pos + dxyz, self.ee_min, self.ee_max)

        joint_poses = self._ik_to(target_ee)

        for i, j in enumerate(self.arm_joint_indices):
            p.setJointMotorControl2(
                self.panda, j,
                p.POSITION_CONTROL,
                targetPosition=float(joint_poses[j]),
                force=200,
                physicsClientId=self._client
            )

        # Gripper: grip_cmd < 0 close, > 0 open
        current_open = self._get_gripper_opening()
        delta_open = 0.01 * grip_cmd
        self._set_gripper(current_open + delta_open)

    def _get_obs(self):
        ee_pos, ee_vel = self._get_ee_state()
        cube_pos, cube_orn = p.getBasePositionAndOrientation(self.cube_id, physicsClientId=self._client)
        cube_vel_lin, cube_vel_ang = p.getBaseVelocity(self.cube_id, physicsClientId=self._client)

        cube_pos = np.array(cube_pos, dtype=np.float32)
        cube_vel = np.array(cube_vel_lin, dtype=np.float32)

        target = self.target_pos.astype(np.float32)
        cube_size = (2.0 * self.cube_half_extents).astype(np.float32)  # full extents
        grip_open = np.array([self._get_gripper_opening()], dtype=np.float32)

        obs = np.concatenate([ee_pos, ee_vel, cube_pos, cube_vel, target, cube_size, grip_open], axis=0)
        return obs

    def _compute_reward_done_info(self):
        ee_pos, _ = self._get_ee_state()
        cube_pos, _ = p.getBasePositionAndOrientation(self.cube_id, physicsClientId=self._client)
        cube_pos = np.array(cube_pos, dtype=np.float32)

        # Distances
        d_ee_cube = float(np.linalg.norm(ee_pos - cube_pos))
        d_cube_goal = float(np.linalg.norm(cube_pos - self.target_pos))

        # "Lifted" heuristic
        lifted = cube_pos[2] > 0.08

        # Dense reward shaping
        reward = -1.0 * d_ee_cube - 2.0 * d_cube_goal
        if lifted:
            reward += 1.0

        success = (d_cube_goal < 0.05) and (cube_pos[2] < 0.06)
        if success:
            reward += 10.0

        terminated = bool(success)
        truncated = bool(self._step_count >= self.episode_len)

        info = {"success": success, "d_ee_cube": d_ee_cube, "d_cube_goal": d_cube_goal}
        return reward, terminated, truncated, info

    def reset(self, *, seed=None, options=None):
        super().reset(seed=seed)
        if seed is not None:
            self._rng = np.random.default_rng(seed)
        self._connect()
        self._load_scene()
        self._step_count = 0

        obs = self._get_obs()
        info = {}
        return obs, info

    def step(self, action):
        self._apply_action(action)
        for _ in range(self.sim_steps_per_action):
            p.stepSimulation(physicsClientId=self._client)
            if self.render_mode == "human":
                time.sleep(1.0 / 240.0)

        self._step_count += 1
        obs = self._get_obs()
        reward, terminated, truncated, info = self._compute_reward_done_info()
        return obs, reward, terminated, truncated, info

    def render(self):
        if self.render_mode != "rgb_array":
            return None
        # Simple camera view
        view = p.computeViewMatrixFromYawPitchRoll(
            cameraTargetPosition=[0.55, 0.0, 0.1],
            distance=0.8,
            yaw=45,
            pitch=-35,
            roll=0,
            upAxisIndex=2,
            physicsClientId=self._client,
        )
        proj = p.computeProjectionMatrixFOV(fov=60, aspect=16/9, nearVal=0.01, farVal=3.0)
        w, h, rgba, _, _ = p.getCameraImage(960, 540, viewMatrix=view, projectionMatrix=proj, physicsClientId=self._client)
        img = np.array(rgba, dtype=np.uint8).reshape(h, w, 4)
        return img

    def close(self):
        if self._client is not None:
            p.disconnect(physicsClientId=self._client)
            self._client = None

# %%
def make_env(rank: int, seed: int = 0):
    def _init():
        env = PandaPickCubeEnv(render_mode=None, seed=seed + rank)
        return env
    return _init

# %%
mp.set_start_method("forkserver", force=True)

n_envs = min(32, mp.cpu_count())

env = SubprocVecEnv([make_env(i) for i in range(n_envs)])
env = VecMonitor(env)

model = PPO(
    "MlpPolicy",
    env,
    device="cpu",
    verbose=1,
    n_steps=1024,
    batch_size=4096,
    n_epochs=10,
    learning_rate=3e-4,
    gamma=0.99,
)

model.learn(total_timesteps=2_000_000)
model.save("ppo_panda_pick")
env.close()
# Out:
# pybullet build time: Jan 29 2025 23:16:28
# pybullet build time: Jan 29 2025 23:16:28
# pybullet build time: Jan 29 2025 23:16:28
# pybullet build time: Jan 29 2025 23:16:28
# pybullet build time: Jan 29 2025 23:16:28
# pybullet build time: Jan 29 2025 23:16:28
# pybullet build time: Jan 29 2025 23:16:28
# pybullet build time: Jan 29 2025 23:16:28
# pybullet build time: Jan 29 2025 23:16:28
# pybullet build time: Jan 29 2025 23:16:28
# pybullet build time: Jan 29 2025 23:16:28
# pybullet build time: Jan 29 2025 23:16:28
# pybullet build time: Jan 29 2025 23:16:28
# pybullet build time: Jan 29 2025 23:16:28
# pybullet build time: Jan 29 2025 23:16:28
# pybullet build time: Jan 29 2025 23:16:28
# pybullet build time: Jan 29 2025 23:16:28
# pybullet build time: Jan 29 2025 23:16:28
# pybullet build time: Jan 29 2025 23:16:28
# pybullet build time: Jan 29 2025 23:16:28
# pybullet build time: Jan 29 2025 23:16:28
# pybullet build time: Jan 29 2025 23:16:28
# pybullet build time: Jan 29 2025 23:16:28
# pybullet build time: Jan 29 2025 23:16:28
# pybullet build time: Jan 29 2025 23:16:28
# pybullet build time: Jan 29 2025 23:16:28
# pybullet build time: Jan 29 2025 23:16:28
# pybullet build time: Jan 29 2025 23:16:28
# pybullet build time: Jan 29 2025 23:16:28
# pybullet build time: Jan 29 2025 23:16:28
# /home/shreyak/venv/lib/python3.10/site-packages/stable_baselines3/ppo/ppo.py:155: UserWarning: You have specified a mini-batch size of 4096, but because the `RolloutBuffer` is of size `n_steps * n_envs = 30720`, after every 7 untruncated mini-batches, there will be a truncated mini-batch of size 2048
# We recommend using a `batch_size` that is a factor of `n_steps * n_envs`.
# Info: (n_steps=1024 and n_envs=30)
#   warnings.warn(
# Using cpu device
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 180      |
# |    ep_rew_mean     | -142     |
# | time/              |          |
# |    fps             | 4344     |
# |    iterations      | 1        |
# |    time_elapsed    | 7        |
# |    total_timesteps | 30720    |
# ---------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 178          |
# |    ep_rew_mean          | -128         |
# | time/                   |              |
# |    fps                  | 4218         |
# |    iterations           | 2            |
# |    time_elapsed         | 14           |
# |    total_timesteps      | 61440        |
# | train/                  |              |
# |    approx_kl            | 0.0050018444 |
# |    clip_fraction        | 0.0303       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -5.67        |
# |    explained_variance   | 0.000636     |
# |    learning_rate        | 0.0003       |
# |    loss                 | 48.8         |
# |    n_updates            | 10           |
# |    policy_gradient_loss | -0.00246     |
# |    std                  | 0.999        |
# |    value_loss           | 129          |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 184         |
# |    ep_rew_mean          | -124        |
# | time/                   |             |
# |    fps                  | 4103        |
# |    iterations           | 3           |
# |    time_elapsed         | 22          |
# |    total_timesteps      | 92160       |
# | train/                  |             |
# |    approx_kl            | 0.004344421 |
# |    clip_fraction        | 0.0216      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -5.66       |
# |    explained_variance   | 0.0206      |
# |    learning_rate        | 0.0003      |
# |    loss                 | 28.5        |
# |    n_updates            | 20          |
# |    policy_gradient_loss | -0.00204    |
# |    std                  | 0.993       |
# |    value_loss           | 87.4        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 182         |
# |    ep_rew_mean          | -115        |
# | time/                   |             |
# |    fps                  | 3924        |
# |    iterations           | 4           |
# |    time_elapsed         | 31          |
# |    total_timesteps      | 122880      |
# | train/                  |             |
# |    approx_kl            | 0.003832539 |
# |    clip_fraction        | 0.0171      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -5.65       |
# |    explained_variance   | 0.0431      |
# |    learning_rate        | 0.0003      |
# |    loss                 | 24.3        |
# |    n_updates            | 30          |
# |    policy_gradient_loss | -0.00171    |
# |    std                  | 0.995       |
# |    value_loss           | 70          |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 182          |
# |    ep_rew_mean          | -105         |
# | time/                   |              |
# |    fps                  | 3790         |
# |    iterations           | 5            |
# |    time_elapsed         | 40           |
# |    total_timesteps      | 153600       |
# | train/                  |              |
# |    approx_kl            | 0.0044909227 |
# |    clip_fraction        | 0.0223       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -5.65        |
# |    explained_variance   | 0.0395       |
# |    learning_rate        | 0.0003       |
# |    loss                 | 19.4         |
# |    n_updates            | 40           |
# |    policy_gradient_loss | -0.00203     |
# |    std                  | 0.994        |
# |    value_loss           | 53.9         |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 172          |
# |    ep_rew_mean          | -94.2        |
# | time/                   |              |
# |    fps                  | 3608         |
# |    iterations           | 6            |
# |    time_elapsed         | 51           |
# |    total_timesteps      | 184320       |
# | train/                  |              |
# |    approx_kl            | 0.0037258451 |
# |    clip_fraction        | 0.015        |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -5.65        |
# |    explained_variance   | 0.0371       |
# |    learning_rate        | 0.0003       |
# |    loss                 | 16.1         |
# |    n_updates            | 50           |
# |    policy_gradient_loss | -0.0015      |
# |    std                  | 0.993        |
# |    value_loss           | 43.6         |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 177          |
# |    ep_rew_mean          | -94.2        |
# | time/                   |              |
# |    fps                  | 3450         |
# |    iterations           | 7            |
# |    time_elapsed         | 62           |
# |    total_timesteps      | 215040       |
# | train/                  |              |
# |    approx_kl            | 0.0042191036 |
# |    clip_fraction        | 0.0216       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -5.63        |
# |    explained_variance   | 0.0224       |
# |    learning_rate        | 0.0003       |
# |    loss                 | 12.8         |
# |    n_updates            | 60           |
# |    policy_gradient_loss | -0.00201     |
# |    std                  | 0.986        |
# |    value_loss           | 34.7         |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 179          |
# |    ep_rew_mean          | -93.2        |
# | time/                   |              |
# |    fps                  | 3287         |
# |    iterations           | 8            |
# |    time_elapsed         | 74           |
# |    total_timesteps      | 245760       |
# | train/                  |              |
# |    approx_kl            | 0.0031264867 |
# |    clip_fraction        | 0.0137       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -5.61        |
# |    explained_variance   | 0.0142       |
# |    learning_rate        | 0.0003       |
# |    loss                 | 11.4         |
# |    n_updates            | 70           |
# |    policy_gradient_loss | -0.00123     |
# |    std                  | 0.983        |
# |    value_loss           | 31.8         |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 179          |
# |    ep_rew_mean          | -93.2        |
# | time/                   |              |
# |    fps                  | 3077         |
# |    iterations           | 9            |
# |    time_elapsed         | 89           |
# |    total_timesteps      | 276480       |
# | train/                  |              |
# |    approx_kl            | 0.0037564975 |
# |    clip_fraction        | 0.0158       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -5.6         |
# |    explained_variance   | 0.0146       |
# |    learning_rate        | 0.0003       |
# |    loss                 | 10.3         |
# |    n_updates            | 80           |
# |    policy_gradient_loss | -0.00133     |
# |    std                  | 0.98         |
# |    value_loss           | 26.4         |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 172         |
# |    ep_rew_mean          | -86.6       |
# | time/                   |             |
# |    fps                  | 2923        |
# |    iterations           | 10          |
# |    time_elapsed         | 105         |
# |    total_timesteps      | 307200      |
# | train/                  |             |
# |    approx_kl            | 0.003323013 |
# |    clip_fraction        | 0.0169      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -5.59       |
# |    explained_variance   | 0.00716     |
# |    learning_rate        | 0.0003      |
# |    loss                 | 9.92        |
# |    n_updates            | 90          |
# |    policy_gradient_loss | -0.00149    |
# |    std                  | 0.977       |
# |    value_loss           | 25.9        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 173         |
# |    ep_rew_mean          | -90         |
# | time/                   |             |
# |    fps                  | 2785        |
# |    iterations           | 11          |
# |    time_elapsed         | 121         |
# |    total_timesteps      | 337920      |
# | train/                  |             |
# |    approx_kl            | 0.004395755 |
# |    clip_fraction        | 0.0259      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -5.58       |
# |    explained_variance   | 0.00514     |
# |    learning_rate        | 0.0003      |
# |    loss                 | 8.03        |
# |    n_updates            | 100         |
# |    policy_gradient_loss | -0.00198    |
# |    std                  | 0.974       |
# |    value_loss           | 21.2        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 172         |
# |    ep_rew_mean          | -85.6       |
# | time/                   |             |
# |    fps                  | 2663        |
# |    iterations           | 12          |
# |    time_elapsed         | 138         |
# |    total_timesteps      | 368640      |
# | train/                  |             |
# |    approx_kl            | 0.003222135 |
# |    clip_fraction        | 0.00861     |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -5.56       |
# |    explained_variance   | 0.00247     |
# |    learning_rate        | 0.0003      |
# |    loss                 | 7.19        |
# |    n_updates            | 110         |
# |    policy_gradient_loss | -0.00088    |
# |    std                  | 0.971       |
# |    value_loss           | 20.1        |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 166          |
# |    ep_rew_mean          | -85          |
# | time/                   |              |
# |    fps                  | 2554         |
# |    iterations           | 13           |
# |    time_elapsed         | 156          |
# |    total_timesteps      | 399360       |
# | train/                  |              |
# |    approx_kl            | 0.0027169702 |
# |    clip_fraction        | 0.00662      |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -5.55        |
# |    explained_variance   | 0.00257      |
# |    learning_rate        | 0.0003       |
# |    loss                 | 7.59         |
# |    n_updates            | 120          |
# |    policy_gradient_loss | -0.000738    |
# |    std                  | 0.967        |
# |    value_loss           | 18.6         |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 173          |
# |    ep_rew_mean          | -88.9        |
# | time/                   |              |
# |    fps                  | 2462         |
# |    iterations           | 14           |
# |    time_elapsed         | 174          |
# |    total_timesteps      | 430080       |
# | train/                  |              |
# |    approx_kl            | 0.0034275171 |
# |    clip_fraction        | 0.0122       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -5.53        |
# |    explained_variance   | 0.00404      |
# |    learning_rate        | 0.0003       |
# |    loss                 | 5.39         |
# |    n_updates            | 130          |
# |    policy_gradient_loss | -0.000984    |
# |    std                  | 0.964        |
# |    value_loss           | 14.7         |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 171          |
# |    ep_rew_mean          | -85          |
# | time/                   |              |
# |    fps                  | 2390         |
# |    iterations           | 15           |
# |    time_elapsed         | 192          |
# |    total_timesteps      | 460800       |
# | train/                  |              |
# |    approx_kl            | 0.0041588694 |
# |    clip_fraction        | 0.0145       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -5.51        |
# |    explained_variance   | 0.00245      |
# |    learning_rate        | 0.0003       |
# |    loss                 | 5.42         |
# |    n_updates            | 140          |
# |    policy_gradient_loss | -0.00144     |
# |    std                  | 0.956        |
# |    value_loss           | 14.4         |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 174          |
# |    ep_rew_mean          | -83.7        |
# | time/                   |              |
# |    fps                  | 2338         |
# |    iterations           | 16           |
# |    time_elapsed         | 210          |
# |    total_timesteps      | 491520       |
# | train/                  |              |
# |    approx_kl            | 0.0036972843 |
# |    clip_fraction        | 0.0147       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -5.48        |
# |    explained_variance   | 0.00235      |
# |    learning_rate        | 0.0003       |
# |    loss                 | 7.11         |
# |    n_updates            | 150          |
# |    policy_gradient_loss | -0.00142     |
# |    std                  | 0.948        |
# |    value_loss           | 14.7         |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 172          |
# |    ep_rew_mean          | -81.1        |
# | time/                   |              |
# |    fps                  | 2272         |
# |    iterations           | 17           |
# |    time_elapsed         | 229          |
# |    total_timesteps      | 522240       |
# | train/                  |              |
# |    approx_kl            | 0.0021832786 |
# |    clip_fraction        | 0.00911      |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -5.45        |
# |    explained_variance   | 0.00141      |
# |    learning_rate        | 0.0003       |
# |    loss                 | 5.63         |
# |    n_updates            | 160          |
# |    policy_gradient_loss | -0.000723    |
# |    std                  | 0.945        |
# |    value_loss           | 12.3         |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 185          |
# |    ep_rew_mean          | -89.6        |
# | time/                   |              |
# |    fps                  | 2223         |
# |    iterations           | 18           |
# |    time_elapsed         | 248          |
# |    total_timesteps      | 552960       |
# | train/                  |              |
# |    approx_kl            | 0.0034925123 |
# |    clip_fraction        | 0.0111       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -5.44        |
# |    explained_variance   | 0.00143      |
# |    learning_rate        | 0.0003       |
# |    loss                 | 5.59         |
# |    n_updates            | 170          |
# |    policy_gradient_loss | -0.00117     |
# |    std                  | 0.941        |
# |    value_loss           | 13.4         |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 171         |
# |    ep_rew_mean          | -80         |
# | time/                   |             |
# |    fps                  | 2178        |
# |    iterations           | 19          |
# |    time_elapsed         | 267         |
# |    total_timesteps      | 583680      |
# | train/                  |             |
# |    approx_kl            | 0.003772221 |
# |    clip_fraction        | 0.0133      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -5.42       |
# |    explained_variance   | 0.00163     |
# |    learning_rate        | 0.0003      |
# |    loss                 | 3.6         |
# |    n_updates            | 180         |
# |    policy_gradient_loss | -0.00119    |
# |    std                  | 0.936       |
# |    value_loss           | 8.88        |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 178          |
# |    ep_rew_mean          | -84.6        |
# | time/                   |              |
# |    fps                  | 2144         |
# |    iterations           | 20           |
# |    time_elapsed         | 286          |
# |    total_timesteps      | 614400       |
# | train/                  |              |
# |    approx_kl            | 0.0027906958 |
# |    clip_fraction        | 0.0139       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -5.4         |
# |    explained_variance   | 0.000889     |
# |    learning_rate        | 0.0003       |
# |    loss                 | 7.46         |
# |    n_updates            | 190          |
# |    policy_gradient_loss | -0.000971    |
# |    std                  | 0.93         |
# |    value_loss           | 13.7         |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 189          |
# |    ep_rew_mean          | -98.2        |
# | time/                   |              |
# |    fps                  | 2111         |
# |    iterations           | 21           |
# |    time_elapsed         | 305          |
# |    total_timesteps      | 645120       |
# | train/                  |              |
# |    approx_kl            | 0.0024651473 |
# |    clip_fraction        | 0.0165       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -5.38        |
# |    explained_variance   | 0.000899     |
# |    learning_rate        | 0.0003       |
# |    loss                 | 6.05         |
# |    n_updates            | 200          |
# |    policy_gradient_loss | -0.000694    |
# |    std                  | 0.927        |
# |    value_loss           | 13.1         |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 181          |
# |    ep_rew_mean          | -90.9        |
# | time/                   |              |
# |    fps                  | 2081         |
# |    iterations           | 22           |
# |    time_elapsed         | 324          |
# |    total_timesteps      | 675840       |
# | train/                  |              |
# |    approx_kl            | 0.0033245021 |
# |    clip_fraction        | 0.0297       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -5.37        |
# |    explained_variance   | 0.000568     |
# |    learning_rate        | 0.0003       |
# |    loss                 | 4.04         |
# |    n_updates            | 210          |
# |    policy_gradient_loss | 7.76e-05     |
# |    std                  | 0.923        |
# |    value_loss           | 10.1         |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 174          |
# |    ep_rew_mean          | -79.6        |
# | time/                   |              |
# |    fps                  | 2060         |
# |    iterations           | 23           |
# |    time_elapsed         | 342          |
# |    total_timesteps      | 706560       |
# | train/                  |              |
# |    approx_kl            | 0.0046341023 |
# |    clip_fraction        | 0.0178       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -5.33        |
# |    explained_variance   | 0.000986     |
# |    learning_rate        | 0.0003       |
# |    loss                 | 5.88         |
# |    n_updates            | 220          |
# |    policy_gradient_loss | -0.000655    |
# |    std                  | 0.91         |
# |    value_loss           | 12.6         |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 184          |
# |    ep_rew_mean          | -85.8        |
# | time/                   |              |
# |    fps                  | 2037         |
# |    iterations           | 24           |
# |    time_elapsed         | 361          |
# |    total_timesteps      | 737280       |
# | train/                  |              |
# |    approx_kl            | 0.0049256315 |
# |    clip_fraction        | 0.0325       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -5.27        |
# |    explained_variance   | 0.000705     |
# |    learning_rate        | 0.0003       |
# |    loss                 | 6.97         |
# |    n_updates            | 230          |
# |    policy_gradient_loss | -0.00193     |
# |    std                  | 0.902        |
# |    value_loss           | 13.6         |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 175         |
# |    ep_rew_mean          | -83.3       |
# | time/                   |             |
# |    fps                  | 2011        |
# |    iterations           | 25          |
# |    time_elapsed         | 381         |
# |    total_timesteps      | 768000      |
# | train/                  |             |
# |    approx_kl            | 0.002912993 |
# |    clip_fraction        | 0.0119      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -5.26       |
# |    explained_variance   | 0.00279     |
# |    learning_rate        | 0.0003      |
# |    loss                 | 4.08        |
# |    n_updates            | 240         |
# |    policy_gradient_loss | -0.000968   |
# |    std                  | 0.901       |
# |    value_loss           | 8.92        |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 172          |
# |    ep_rew_mean          | -79.1        |
# | time/                   |              |
# |    fps                  | 1986         |
# |    iterations           | 26           |
# |    time_elapsed         | 402          |
# |    total_timesteps      | 798720       |
# | train/                  |              |
# |    approx_kl            | 0.0027960115 |
# |    clip_fraction        | 0.0198       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -5.26        |
# |    explained_variance   | 0.00253      |
# |    learning_rate        | 0.0003       |
# |    loss                 | 9.26         |
# |    n_updates            | 250          |
# |    policy_gradient_loss | -0.00142     |
# |    std                  | 0.904        |
# |    value_loss           | 19.5         |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 170         |
# |    ep_rew_mean          | -79.2       |
# | time/                   |             |
# |    fps                  | 1967        |
# |    iterations           | 27          |
# |    time_elapsed         | 421         |
# |    total_timesteps      | 829440      |
# | train/                  |             |
# |    approx_kl            | 0.004428341 |
# |    clip_fraction        | 0.0229      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -5.27       |
# |    explained_variance   | 0.0248      |
# |    learning_rate        | 0.0003      |
# |    loss                 | 7.8         |
# |    n_updates            | 260         |
# |    policy_gradient_loss | -0.00128    |
# |    std                  | 0.904       |
# |    value_loss           | 13          |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 167          |
# |    ep_rew_mean          | -80.7        |
# | time/                   |              |
# |    fps                  | 1951         |
# |    iterations           | 28           |
# |    time_elapsed         | 440          |
# |    total_timesteps      | 860160       |
# | train/                  |              |
# |    approx_kl            | 0.0035483055 |
# |    clip_fraction        | 0.0173       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -5.26        |
# |    explained_variance   | 0.0305       |
# |    learning_rate        | 0.0003       |
# |    loss                 | 5.12         |
# |    n_updates            | 270          |
# |    policy_gradient_loss | -0.00137     |
# |    std                  | 0.901        |
# |    value_loss           | 13.2         |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 169          |
# |    ep_rew_mean          | -79.3        |
# | time/                   |              |
# |    fps                  | 1934         |
# |    iterations           | 29           |
# |    time_elapsed         | 460          |
# |    total_timesteps      | 890880       |
# | train/                  |              |
# |    approx_kl            | 0.0038233188 |
# |    clip_fraction        | 0.0148       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -5.24        |
# |    explained_variance   | 0.054        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 5.72         |
# |    n_updates            | 280          |
# |    policy_gradient_loss | -0.00121     |
# |    std                  | 0.896        |
# |    value_loss           | 11.7         |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 171         |
# |    ep_rew_mean          | -80.2       |
# | time/                   |             |
# |    fps                  | 1918        |
# |    iterations           | 30          |
# |    time_elapsed         | 480         |
# |    total_timesteps      | 921600      |
# | train/                  |             |
# |    approx_kl            | 0.003586188 |
# |    clip_fraction        | 0.023       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -5.21       |
# |    explained_variance   | 0.0775      |
# |    learning_rate        | 0.0003      |
# |    loss                 | 3.72        |
# |    n_updates            | 290         |
# |    policy_gradient_loss | -0.00179    |
# |    std                  | 0.888       |
# |    value_loss           | 13.2        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 182         |
# |    ep_rew_mean          | -85.2       |
# | time/                   |             |
# |    fps                  | 1905        |
# |    iterations           | 31          |
# |    time_elapsed         | 499         |
# |    total_timesteps      | 952320      |
# | train/                  |             |
# |    approx_kl            | 0.004410954 |
# |    clip_fraction        | 0.034       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -5.19       |
# |    explained_variance   | 0.116       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 7           |
# |    n_updates            | 300         |
# |    policy_gradient_loss | -0.00147    |
# |    std                  | 0.887       |
# |    value_loss           | 15.7        |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 175          |
# |    ep_rew_mean          | -79.9        |
# | time/                   |              |
# |    fps                  | 1895         |
# |    iterations           | 32           |
# |    time_elapsed         | 518          |
# |    total_timesteps      | 983040       |
# | train/                  |              |
# |    approx_kl            | 0.0040735602 |
# |    clip_fraction        | 0.021        |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -5.19        |
# |    explained_variance   | 0.202        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 4.68         |
# |    n_updates            | 310          |
# |    policy_gradient_loss | -0.00198     |
# |    std                  | 0.886        |
# |    value_loss           | 11.3         |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 156          |
# |    ep_rew_mean          | -67.5        |
# | time/                   |              |
# |    fps                  | 1887         |
# |    iterations           | 33           |
# |    time_elapsed         | 536          |
# |    total_timesteps      | 1013760      |
# | train/                  |              |
# |    approx_kl            | 0.0031666541 |
# |    clip_fraction        | 0.0233       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -5.18        |
# |    explained_variance   | 0.179        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 5.35         |
# |    n_updates            | 320          |
# |    policy_gradient_loss | -0.0013      |
# |    std                  | 0.885        |
# |    value_loss           | 13.6         |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 170         |
# |    ep_rew_mean          | -77.6       |
# | time/                   |             |
# |    fps                  | 1878        |
# |    iterations           | 34          |
# |    time_elapsed         | 556         |
# |    total_timesteps      | 1044480     |
# | train/                  |             |
# |    approx_kl            | 0.003481345 |
# |    clip_fraction        | 0.0309      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -5.18       |
# |    explained_variance   | 0.162       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 7.06        |
# |    n_updates            | 330         |
# |    policy_gradient_loss | -0.00253    |
# |    std                  | 0.884       |
# |    value_loss           | 14.1        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 183         |
# |    ep_rew_mean          | -88.7       |
# | time/                   |             |
# |    fps                  | 1868        |
# |    iterations           | 35          |
# |    time_elapsed         | 575         |
# |    total_timesteps      | 1075200     |
# | train/                  |             |
# |    approx_kl            | 0.004623831 |
# |    clip_fraction        | 0.0334      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -5.17       |
# |    explained_variance   | 0.169       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 6.56        |
# |    n_updates            | 340         |
# |    policy_gradient_loss | -0.00226    |
# |    std                  | 0.884       |
# |    value_loss           | 14.4        |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 180          |
# |    ep_rew_mean          | -83.1        |
# | time/                   |              |
# |    fps                  | 1861         |
# |    iterations           | 36           |
# |    time_elapsed         | 594          |
# |    total_timesteps      | 1105920      |
# | train/                  |              |
# |    approx_kl            | 0.0029634344 |
# |    clip_fraction        | 0.00916      |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -5.17        |
# |    explained_variance   | 0.222        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 8.17         |
# |    n_updates            | 350          |
# |    policy_gradient_loss | -0.000682    |
# |    std                  | 0.883        |
# |    value_loss           | 11.8         |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 181          |
# |    ep_rew_mean          | -86.3        |
# | time/                   |              |
# |    fps                  | 1853         |
# |    iterations           | 37           |
# |    time_elapsed         | 613          |
# |    total_timesteps      | 1136640      |
# | train/                  |              |
# |    approx_kl            | 0.0035110593 |
# |    clip_fraction        | 0.0198       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -5.17        |
# |    explained_variance   | 0.268        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 4.78         |
# |    n_updates            | 360          |
# |    policy_gradient_loss | -0.00152     |
# |    std                  | 0.881        |
# |    value_loss           | 9.66         |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 178          |
# |    ep_rew_mean          | -82.9        |
# | time/                   |              |
# |    fps                  | 1846         |
# |    iterations           | 38           |
# |    time_elapsed         | 632          |
# |    total_timesteps      | 1167360      |
# | train/                  |              |
# |    approx_kl            | 0.0038675698 |
# |    clip_fraction        | 0.0218       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -5.15        |
# |    explained_variance   | 0.328        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 4.68         |
# |    n_updates            | 370          |
# |    policy_gradient_loss | -0.00175     |
# |    std                  | 0.88         |
# |    value_loss           | 8.32         |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 171         |
# |    ep_rew_mean          | -74.9       |
# | time/                   |             |
# |    fps                  | 1841        |
# |    iterations           | 39          |
# |    time_elapsed         | 650         |
# |    total_timesteps      | 1198080     |
# | train/                  |             |
# |    approx_kl            | 0.003518701 |
# |    clip_fraction        | 0.0177      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -5.15       |
# |    explained_variance   | 0.286       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 5.06        |
# |    n_updates            | 380         |
# |    policy_gradient_loss | -0.00129    |
# |    std                  | 0.877       |
# |    value_loss           | 11.1        |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 170          |
# |    ep_rew_mean          | -81.1        |
# | time/                   |              |
# |    fps                  | 1836         |
# |    iterations           | 40           |
# |    time_elapsed         | 669          |
# |    total_timesteps      | 1228800      |
# | train/                  |              |
# |    approx_kl            | 0.0026571816 |
# |    clip_fraction        | 0.00748      |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -5.14        |
# |    explained_variance   | 0.217        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 9.49         |
# |    n_updates            | 390          |
# |    policy_gradient_loss | -0.000879    |
# |    std                  | 0.877        |
# |    value_loss           | 13.4         |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 175          |
# |    ep_rew_mean          | -78.3        |
# | time/                   |              |
# |    fps                  | 1828         |
# |    iterations           | 41           |
# |    time_elapsed         | 688          |
# |    total_timesteps      | 1259520      |
# | train/                  |              |
# |    approx_kl            | 0.0038357014 |
# |    clip_fraction        | 0.0147       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -5.13        |
# |    explained_variance   | 0.258        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 7.46         |
# |    n_updates            | 400          |
# |    policy_gradient_loss | -0.00155     |
# |    std                  | 0.875        |
# |    value_loss           | 14.5         |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 166          |
# |    ep_rew_mean          | -71.5        |
# | time/                   |              |
# |    fps                  | 1822         |
# |    iterations           | 42           |
# |    time_elapsed         | 707          |
# |    total_timesteps      | 1290240      |
# | train/                  |              |
# |    approx_kl            | 0.0027850373 |
# |    clip_fraction        | 0.00691      |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -5.12        |
# |    explained_variance   | 0.468        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 2.58         |
# |    n_updates            | 410          |
# |    policy_gradient_loss | -0.000871    |
# |    std                  | 0.871        |
# |    value_loss           | 8.84         |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 166          |
# |    ep_rew_mean          | -75.5        |
# | time/                   |              |
# |    fps                  | 1818         |
# |    iterations           | 43           |
# |    time_elapsed         | 726          |
# |    total_timesteps      | 1320960      |
# | train/                  |              |
# |    approx_kl            | 0.0025165305 |
# |    clip_fraction        | 0.00658      |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -5.1         |
# |    explained_variance   | 0.394        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 7.51         |
# |    n_updates            | 420          |
# |    policy_gradient_loss | -0.000695    |
# |    std                  | 0.866        |
# |    value_loss           | 14.1         |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 166          |
# |    ep_rew_mean          | -76.2        |
# | time/                   |              |
# |    fps                  | 1811         |
# |    iterations           | 44           |
# |    time_elapsed         | 746          |
# |    total_timesteps      | 1351680      |
# | train/                  |              |
# |    approx_kl            | 0.0032766077 |
# |    clip_fraction        | 0.0108       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -5.07        |
# |    explained_variance   | 0.401        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 6.77         |
# |    n_updates            | 430          |
# |    policy_gradient_loss | -0.000978    |
# |    std                  | 0.861        |
# |    value_loss           | 17.4         |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 161          |
# |    ep_rew_mean          | -75.5        |
# | time/                   |              |
# |    fps                  | 1802         |
# |    iterations           | 45           |
# |    time_elapsed         | 766          |
# |    total_timesteps      | 1382400      |
# | train/                  |              |
# |    approx_kl            | 0.0039638304 |
# |    clip_fraction        | 0.0141       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -5.06        |
# |    explained_variance   | 0.581        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 4.69         |
# |    n_updates            | 440          |
# |    policy_gradient_loss | -0.00103     |
# |    std                  | 0.86         |
# |    value_loss           | 10.2         |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 179          |
# |    ep_rew_mean          | -81.5        |
# | time/                   |              |
# |    fps                  | 1797         |
# |    iterations           | 46           |
# |    time_elapsed         | 786          |
# |    total_timesteps      | 1413120      |
# | train/                  |              |
# |    approx_kl            | 0.0034240556 |
# |    clip_fraction        | 0.0148       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -5.05        |
# |    explained_variance   | 0.523        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 8.81         |
# |    n_updates            | 450          |
# |    policy_gradient_loss | -0.000987    |
# |    std                  | 0.858        |
# |    value_loss           | 15.1         |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 176          |
# |    ep_rew_mean          | -81.6        |
# | time/                   |              |
# |    fps                  | 1793         |
# |    iterations           | 47           |
# |    time_elapsed         | 804          |
# |    total_timesteps      | 1443840      |
# | train/                  |              |
# |    approx_kl            | 0.0039909217 |
# |    clip_fraction        | 0.0197       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -5.05        |
# |    explained_variance   | 0.697        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 5.23         |
# |    n_updates            | 460          |
# |    policy_gradient_loss | -0.00141     |
# |    std                  | 0.857        |
# |    value_loss           | 8.28         |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 179          |
# |    ep_rew_mean          | -88          |
# | time/                   |              |
# |    fps                  | 1788         |
# |    iterations           | 48           |
# |    time_elapsed         | 824          |
# |    total_timesteps      | 1474560      |
# | train/                  |              |
# |    approx_kl            | 0.0036267724 |
# |    clip_fraction        | 0.0278       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -5.04        |
# |    explained_variance   | 0.607        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 5.04         |
# |    n_updates            | 470          |
# |    policy_gradient_loss | -0.00184     |
# |    std                  | 0.855        |
# |    value_loss           | 11.4         |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 173          |
# |    ep_rew_mean          | -85.7        |
# | time/                   |              |
# |    fps                  | 1783         |
# |    iterations           | 49           |
# |    time_elapsed         | 844          |
# |    total_timesteps      | 1505280      |
# | train/                  |              |
# |    approx_kl            | 0.0023810144 |
# |    clip_fraction        | 0.00954      |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -5.03        |
# |    explained_variance   | 0.701        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 5.69         |
# |    n_updates            | 480          |
# |    policy_gradient_loss | -0.000961    |
# |    std                  | 0.852        |
# |    value_loss           | 10.4         |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 180          |
# |    ep_rew_mean          | -85.8        |
# | time/                   |              |
# |    fps                  | 1780         |
# |    iterations           | 50           |
# |    time_elapsed         | 862          |
# |    total_timesteps      | 1536000      |
# | train/                  |              |
# |    approx_kl            | 0.0032634195 |
# |    clip_fraction        | 0.0101       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -5.02        |
# |    explained_variance   | 0.736        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 5.15         |
# |    n_updates            | 490          |
# |    policy_gradient_loss | -0.000893    |
# |    std                  | 0.853        |
# |    value_loss           | 12           |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 158          |
# |    ep_rew_mean          | -73.3        |
# | time/                   |              |
# |    fps                  | 1776         |
# |    iterations           | 51           |
# |    time_elapsed         | 882          |
# |    total_timesteps      | 1566720      |
# | train/                  |              |
# |    approx_kl            | 0.0040917853 |
# |    clip_fraction        | 0.015        |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -5.02        |
# |    explained_variance   | 0.735        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 4.52         |
# |    n_updates            | 500          |
# |    policy_gradient_loss | -0.00124     |
# |    std                  | 0.851        |
# |    value_loss           | 8.92         |
# ------------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 174        |
# |    ep_rew_mean          | -80.8      |
# | time/                   |            |
# |    fps                  | 1770       |
# |    iterations           | 52         |
# |    time_elapsed         | 902        |
# |    total_timesteps      | 1597440    |
# | train/                  |            |
# |    approx_kl            | 0.00371803 |
# |    clip_fraction        | 0.0162     |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -5.01      |
# |    explained_variance   | 0.691      |
# |    learning_rate        | 0.0003     |
# |    loss                 | 5.94       |
# |    n_updates            | 510        |
# |    policy_gradient_loss | -0.00125   |
# |    std                  | 0.848      |
# |    value_loss           | 13         |
# ----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 170          |
# |    ep_rew_mean          | -81.2        |
# | time/                   |              |
# |    fps                  | 1766         |
# |    iterations           | 53           |
# |    time_elapsed         | 921          |
# |    total_timesteps      | 1628160      |
# | train/                  |              |
# |    approx_kl            | 0.0038744675 |
# |    clip_fraction        | 0.014        |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -4.99        |
# |    explained_variance   | 0.682        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 8.3          |
# |    n_updates            | 520          |
# |    policy_gradient_loss | -0.00112     |
# |    std                  | 0.844        |
# |    value_loss           | 15.1         |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 175          |
# |    ep_rew_mean          | -82          |
# | time/                   |              |
# |    fps                  | 1764         |
# |    iterations           | 54           |
# |    time_elapsed         | 940          |
# |    total_timesteps      | 1658880      |
# | train/                  |              |
# |    approx_kl            | 0.0023950527 |
# |    clip_fraction        | 0.0283       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -4.98        |
# |    explained_variance   | 0.822        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 4.1          |
# |    n_updates            | 530          |
# |    policy_gradient_loss | -0.00171     |
# |    std                  | 0.843        |
# |    value_loss           | 8.12         |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 182          |
# |    ep_rew_mean          | -86.4        |
# | time/                   |              |
# |    fps                  | 1763         |
# |    iterations           | 55           |
# |    time_elapsed         | 958          |
# |    total_timesteps      | 1689600      |
# | train/                  |              |
# |    approx_kl            | 0.0028296872 |
# |    clip_fraction        | 0.00584      |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -4.98        |
# |    explained_variance   | 0.764        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 5.52         |
# |    n_updates            | 540          |
# |    policy_gradient_loss | -0.000691    |
# |    std                  | 0.843        |
# |    value_loss           | 11.6         |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 175          |
# |    ep_rew_mean          | -81.5        |
# | time/                   |              |
# |    fps                  | 1761         |
# |    iterations           | 56           |
# |    time_elapsed         | 976          |
# |    total_timesteps      | 1720320      |
# | train/                  |              |
# |    approx_kl            | 0.0039115604 |
# |    clip_fraction        | 0.0167       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -4.97        |
# |    explained_variance   | 0.765        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 5.51         |
# |    n_updates            | 550          |
# |    policy_gradient_loss | -0.00125     |
# |    std                  | 0.839        |
# |    value_loss           | 11.8         |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 177          |
# |    ep_rew_mean          | -82.5        |
# | time/                   |              |
# |    fps                  | 1760         |
# |    iterations           | 57           |
# |    time_elapsed         | 994          |
# |    total_timesteps      | 1751040      |
# | train/                  |              |
# |    approx_kl            | 0.0035219456 |
# |    clip_fraction        | 0.00848      |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -4.96        |
# |    explained_variance   | 0.782        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 7.61         |
# |    n_updates            | 560          |
# |    policy_gradient_loss | -0.000727    |
# |    std                  | 0.838        |
# |    value_loss           | 12.5         |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 172          |
# |    ep_rew_mean          | -82          |
# | time/                   |              |
# |    fps                  | 1758         |
# |    iterations           | 58           |
# |    time_elapsed         | 1013         |
# |    total_timesteps      | 1781760      |
# | train/                  |              |
# |    approx_kl            | 0.0036079946 |
# |    clip_fraction        | 0.0168       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -4.95        |
# |    explained_variance   | 0.763        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 5.81         |
# |    n_updates            | 570          |
# |    policy_gradient_loss | -0.00178     |
# |    std                  | 0.835        |
# |    value_loss           | 11           |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 188          |
# |    ep_rew_mean          | -88.9        |
# | time/                   |              |
# |    fps                  | 1755         |
# |    iterations           | 59           |
# |    time_elapsed         | 1032         |
# |    total_timesteps      | 1812480      |
# | train/                  |              |
# |    approx_kl            | 0.0030965344 |
# |    clip_fraction        | 0.0113       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -4.94        |
# |    explained_variance   | 0.751        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 8.54         |
# |    n_updates            | 580          |
# |    policy_gradient_loss | -0.00129     |
# |    std                  | 0.834        |
# |    value_loss           | 13.7         |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 182          |
# |    ep_rew_mean          | -88          |
# | time/                   |              |
# |    fps                  | 1752         |
# |    iterations           | 60           |
# |    time_elapsed         | 1051         |
# |    total_timesteps      | 1843200      |
# | train/                  |              |
# |    approx_kl            | 0.0030523583 |
# |    clip_fraction        | 0.0169       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -4.94        |
# |    explained_variance   | 0.778        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 7.5          |
# |    n_updates            | 590          |
# |    policy_gradient_loss | -0.00132     |
# |    std                  | 0.835        |
# |    value_loss           | 10.4         |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 171          |
# |    ep_rew_mean          | -82          |
# | time/                   |              |
# |    fps                  | 1749         |
# |    iterations           | 61           |
# |    time_elapsed         | 1071         |
# |    total_timesteps      | 1873920      |
# | train/                  |              |
# |    approx_kl            | 0.0036692047 |
# |    clip_fraction        | 0.0248       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -4.94        |
# |    explained_variance   | 0.871        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 3.7          |
# |    n_updates            | 600          |
# |    policy_gradient_loss | -0.00177     |
# |    std                  | 0.834        |
# |    value_loss           | 7.69         |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 171          |
# |    ep_rew_mean          | -84          |
# | time/                   |              |
# |    fps                  | 1747         |
# |    iterations           | 62           |
# |    time_elapsed         | 1090         |
# |    total_timesteps      | 1904640      |
# | train/                  |              |
# |    approx_kl            | 0.0023941405 |
# |    clip_fraction        | 0.0147       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -4.93        |
# |    explained_variance   | 0.777        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 4.91         |
# |    n_updates            | 610          |
# |    policy_gradient_loss | -0.000774    |
# |    std                  | 0.831        |
# |    value_loss           | 12.4         |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 166          |
# |    ep_rew_mean          | -73.9        |
# | time/                   |              |
# |    fps                  | 1743         |
# |    iterations           | 63           |
# |    time_elapsed         | 1110         |
# |    total_timesteps      | 1935360      |
# | train/                  |              |
# |    approx_kl            | 0.0034500307 |
# |    clip_fraction        | 0.00825      |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -4.91        |
# |    explained_variance   | 0.806        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 6.14         |
# |    n_updates            | 620          |
# |    policy_gradient_loss | -0.000744    |
# |    std                  | 0.828        |
# |    value_loss           | 13.8         |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 171          |
# |    ep_rew_mean          | -78.9        |
# | time/                   |              |
# |    fps                  | 1740         |
# |    iterations           | 64           |
# |    time_elapsed         | 1129         |
# |    total_timesteps      | 1966080      |
# | train/                  |              |
# |    approx_kl            | 0.0027781404 |
# |    clip_fraction        | 0.0143       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -4.9         |
# |    explained_variance   | 0.816        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 5.71         |
# |    n_updates            | 630          |
# |    policy_gradient_loss | -0.00113     |
# |    std                  | 0.825        |
# |    value_loss           | 13.5         |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 163          |
# |    ep_rew_mean          | -72.5        |
# | time/                   |              |
# |    fps                  | 1736         |
# |    iterations           | 65           |
# |    time_elapsed         | 1149         |
# |    total_timesteps      | 1996800      |
# | train/                  |              |
# |    approx_kl            | 0.0040480206 |
# |    clip_fraction        | 0.024        |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -4.88        |
# |    explained_variance   | 0.773        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 5.7          |
# |    n_updates            | 640          |
# |    policy_gradient_loss | -0.00167     |
# |    std                  | 0.821        |
# |    value_loss           | 14           |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 183          |
# |    ep_rew_mean          | -85.2        |
# | time/                   |              |
# |    fps                  | 1735         |
# |    iterations           | 66           |
# |    time_elapsed         | 1168         |
# |    total_timesteps      | 2027520      |
# | train/                  |              |
# |    approx_kl            | 0.0025312528 |
# |    clip_fraction        | 0.012        |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -4.86        |
# |    explained_variance   | 0.769        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 5.23         |
# |    n_updates            | 650          |
# |    policy_gradient_loss | -0.000857    |
# |    std                  | 0.818        |
# |    value_loss           | 14           |
# ------------------------------------------

# %%
# IMPORTANT: evaluation env must be single-process for video
env = PandaPickCubeEnv(render_mode="rgb_array")

env = RecordVideo(
    env,
    video_folder="./rl_videos",
    episode_trigger=lambda ep: ep == 0,
    name_prefix="panda-pick",
    disable_logger=False,
)

model = PPO.load("ppo_panda_pick", device="cpu")

obs, _ = env.reset()
done = False
while True:
    action, _ = model.predict(obs, deterministic=True)
    obs, reward, terminated, truncated, info = env.step(action)
    if terminated or truncated:
        break

env.close()
print("Saved video(s) to ./rl_videos")
# Out:
# /home/shreyak/venv/lib/python3.10/site-packages/gymnasium/wrappers/rendering.py:293: UserWarning: WARN: Overwriting existing videos at /home/shreyak/rl_videos folder (try specifying a different `video_folder` for the `RecordVideo` wrapper if this is not desired)
#   logger.warn(
# MoviePy - Building video /home/shreyak/rl_videos/panda-pick-episode-0.mp4.
# MoviePy - Writing video /home/shreyak/rl_videos/panda-pick-episode-0.mp4
# MoviePy - Done !
# MoviePy - video ready /home/shreyak/rl_videos/panda-pick-episode-0.mp4
# Saved video(s) to ./rl_videos
